# %% [markdown]
# # Sprint 7: Analisis de Componentes Principales (ACP) y Clustering de IES (Issue 7.2)
#
# Este notebook realiza el agrupamiento de las Instituciones de Educacion Superior (IES)
# en Colombia segun su desempeno academico en las pruebas Saber Pro y sus metricas SNIES
# (matricula, graduacion y acreditacion).
#
# ### Pipeline:
# 1. **Carga memory-safe** de Saber Pro (~2.7M registros, solo columnas necesarias)
# 2. **Integracion SNIES** respetando la regla MEN de semestres para matricula anual
# 3. **Feature engineering** por IES (9 variables)
# 4. **ACP / PCA** para reducir dimensiones (reteniendo >= 70% varianza)
# 5. **K-Means** sobre las componentes principales reducidas (NO sobre variables originales)
# 6. **Biplot** de IES en espacio PC1 vs PC2 con vectores de carga
# 7. **Perfiles de cluster** y auditoria
#
# ### Regla MEN para Matricula Anual SNIES:
# - **Primer semestre**: se cuenta como matricula anual para TODAS las IES excepto el SENA
# - **Segundo semestre**: se cuenta SOLO para el SENA (quienes inician ahi)
# - Esto evita duplicaciones y refleja la metodologia oficial del Ministerio de Educacion Nacional

# %%
# Imports
import warnings
warnings.filterwarnings('ignore')

import os
from pathlib import Path
import json
import pickle
from datetime import datetime

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

# Configuracion de visualizacion
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
# %matplotlib inline

# Rutas
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
DATOS_DIR = PROJECT_ROOT / 'datos' / 'processed'
ARTIFACTS_DIR = PROJECT_ROOT / 'artifacts'

# Crear subdirectorios de artifacts si no existen
for subdir in ['modelos', 'metricas', 'visualizaciones']:
    (ARTIFACTS_DIR / subdir).mkdir(parents=True, exist_ok=True)

print("Setup completo!")
print(f"Ruta del proyecto: {PROJECT_ROOT}")
# Out:
# Setup completo!
# Ruta del proyecto: c:\Users\German\Pictures\Proyecto-Observatorio-Datos-de-Educacion-en-Colombia

# %% [markdown]
# ## 1. Carga de Datos (Memory-Safe)
# Cargamos unicamente las columnas necesarias del dataset unificado de Saber Pro
# (que contiene mas de 2.6M de registros y 150+ columnas originalmente).
# Tambien cargamos los datos de SNIES graduados (para el puente de codigos) y el
# dataset consolidado que ya aplica la regla MEN de semestres.

# %%
# Cargar Saber Pro (filtrado por columnas para optimizar la RAM)
print("Cargando Saber Pro...")
df_saberpro = pd.read_parquet(
    DATOS_DIR / 'saber_pro' / 'saber_pro_consolidado.parquet',
    columns=['nombre_ies', 'puntaje_global', 'punt_razona_cuantitativa',
             'punt_lectura_critica', 'punt_ingles', 'estu_consecutivo', 'codigo_snies_programa']
)
print(f"Saber Pro cargado: {len(df_saberpro):,} registros, {df_saberpro.memory_usage(deep=True).sum()/1e6:.1f} MB")
# Out:
# Cargando Saber Pro...
# Saber Pro cargado: 2,683,632 registros, 312.7 MB

# %% [markdown]
# ## 2. Integracion y Creacion de Features Agregadas por IES (Saber Pro + SNIES)
#
# Calculamos 9 features por cada IES cruzando Saber Pro con SNIES:
#
# | # | Feature | Fuente |
# |---|---------|--------|
# | 1 | `puntaje_global`  | Saber Pro |
# | 2 | `punt_razona_cuantitativa`  | Saber Pro |
# | 3 | `punt_lectura_critica`  | Saber Pro |
# | 4 | `punt_ingles`  | Saber Pro |
# | 5 | `n_presentaciones` (conteo) | Saber Pro |
# | 6 | `prop_p75_plus` (proporcion en percentil 75+) | Saber Pro |
# | 7 | `total_matriculados` (promedio anual, regla MEN) | SNIES |
# | 8 | `total_graduados` (promedio anual) | SNIES |
# | 9 | `es_acreditada` (binario) | SNIES |
#
# **Puente Saber Pro <-> SNIES:** usamos `codigo_snies_programa` como llave comun.
#
# **Regla MEN:** `dataset_snies_consolidado.parquet` ya aplica Sem1 todas IES + Sem2 solo SENA.

# %%
print("Creando features de Saber Pro por IES...")

# Puntajes promedio por IES
features_ies = df_saberpro.groupby('nombre_ies').agg({
    'puntaje_global': 'mean',
    'punt_razona_cuantitativa': 'mean',
    'punt_lectura_critica': 'mean',
    'punt_ingles': 'mean',
    'estu_consecutivo': 'count'
}).rename(columns={'estu_consecutivo': 'n_presentaciones'})

# Calcular proporcion en P75+ (optimizado para memoria)
print("Calculando proporcion P75+...")
p75_global = df_saberpro['puntaje_global'].quantile(0.75)

df_temp = df_saberpro[['nombre_ies', 'puntaje_global']].copy()
df_temp['es_p75_plus'] = (df_temp['puntaje_global'] >= p75_global).astype(int)
prop_p75 = df_temp.groupby('nombre_ies')['es_p75_plus'].mean().rename('prop_p75_plus')
del df_temp  # Liberar memoria

features_ies = features_ies.join(prop_p75)

print("Cruzando con datos del SNIES usando codigo SNIES de programa...")

# 1. Cargar SNIES Graduados crudo para mapear codigo de programa a codigo de IES
df_grad_raw = pd.read_parquet(
    DATOS_DIR / 'snies' / 'snies_graduados_limpio_consolidado.parquet',
    columns=['codigo_snies_programa', 'codigo_institucion', 'ies_acreditada']
)
df_grad_raw['codigo_snies_programa'] = pd.to_numeric(df_grad_raw['codigo_snies_programa'], errors='coerce')
df_grad_raw = df_grad_raw.dropna(subset=['codigo_snies_programa'])

# Relacion unica programa-IES
prog_to_ies = df_grad_raw[['codigo_snies_programa', 'codigo_institucion']].drop_duplicates().dropna()

# 2. Relacion programa-IES en Saber Pro
sp_prog = df_saberpro[['nombre_ies', 'codigo_snies_programa']].drop_duplicates().dropna()
sp_prog['codigo_snies_programa'] = pd.to_numeric(sp_prog['codigo_snies_programa'], errors='coerce')
sp_prog = sp_prog.dropna()

# 3. Cruzar para obtener el mapeo nombre_ies -> codigo_institucion (SNIES)
merged_bridge = pd.merge(sp_prog, prog_to_ies, on='codigo_snies_programa', how='inner')
ies_mapping = merged_bridge.groupby('nombre_ies')['codigo_institucion'].agg(lambda x: x.value_counts().index[0]).reset_index()

# 4. Cargar dataset consolidado de SNIES (YA implementa regla MEN: Sem1 todas + Sem2 solo SENA)
df_snies = pd.read_parquet(DATOS_DIR / 'snies' / 'dataset_snies_consolidado.parquet')

# Promedio anual de graduados y matriculados de SNIES
snies_agg = df_snies.groupby('codigo_institucion').agg({
    'total_matriculados': 'mean',
    'total_graduados': 'mean'
}).reset_index()

# 5. Obtener acreditacion (SI / NO) por IES
df_grad_raw['es_acreditada'] = df_grad_raw['ies_acreditada'].apply(lambda x: 1 if str(x).strip().upper() in ['SI', 'S', '1'] else 0)
ies_acred = df_grad_raw.groupby('codigo_institucion')['es_acreditada'].max().reset_index()

# Unificar agregaciones de SNIES
snies_agg = pd.merge(snies_agg, ies_acred, on='codigo_institucion', how='left')

# Cruzar SNIES con el mapping de nombres
snies_mapped = pd.merge(ies_mapping, snies_agg, on='codigo_institucion', how='inner')

# 6. Unificar features en features_ies
features_ies = pd.merge(features_ies, snies_mapped[['nombre_ies', 'total_matriculados', 'total_graduados', 'es_acreditada']],
                        on='nombre_ies', how='left')

# Filtrar IES con al menos 100 presentaciones para evitar ruido
features_ies = features_ies[features_ies['n_presentaciones'] >= 100].copy()

# Imputar valores nulos de SNIES con la mediana
features_ies['total_matriculados'] = features_ies['total_matriculados'].fillna(features_ies['total_matriculados'].median())
features_ies['total_graduados'] = features_ies['total_graduados'].fillna(features_ies['total_graduados'].median())
features_ies['es_acreditada'] = features_ies['es_acreditada'].fillna(0).astype(int)

# Establecer nombre_ies como indice
features_ies = features_ies.set_index('nombre_ies')

print(f"\nFeatures integradas creadas para {len(features_ies)} IES con >= 100 presentaciones.")
print(f"Variables: {features_ies.columns.tolist()}")
display(features_ies.head(10))
# Out:
# Creando features de Saber Pro por IES...
# Calculando proporcion P75+...
# Cruzando con datos del SNIES usando codigo SNIES de programa...
#
# Features integradas creadas para 336 IES con >= 100 presentaciones.
# Variables: ['puntaje_global', 'punt_razona_cuantitativa', 'punt_lectura_critica', 'punt_ingles', 'n_presentaciones', 'prop_p75_plus', 'total_matriculados', 'total_graduados', 'es_acreditada']
#                                                     puntaje_global  \
# nombre_ies
# CENTRO DE EDUCACION MILITAR-BOGOTÃ D.C.                125.365697
# COLEGIO DE ESTUDIOS SUPERIORES DE ADMINISTRACIO...      167.599080
# COLEGIO MAYOR DE ANTIOQUIA-MEDELLIN                     134.239433
# COLEGIO MAYOR DE BOLIVAR-CARTAGENA                       68.701544
# COLEGIO MAYOR DE NUESTRA SEÃORA DEL ROSARIO-BO...      163.442073
# COLEGIO MAYOR DEL CAUCA-POPAYAN                         120.756553
# CONSERVATORIO DEL TOLIMA-IBAGUE                         127.802783
# CORPORACION ACADEMIA SUPERIOR DE ARTES-MEDELLIN          10.165111
# CORPORACION COLEGIATURA COLOMBIANA-MEDELLIN             136.990625
# CORPORACION DE EDUCACION TECNOLOGICA COLSUBSIDI...        9.905837
#
#                                                     punt_razona_cuantitativa  \
# nombre_ies
# CENTRO DE EDUCACION MILITAR-BOGOTÃ D.C.                          135.023394
# COLEGIO DE ESTUDIOS SUPERIORES DE ADMINISTRACIO...                165.724499
# COLEGIO MAYOR DE ANTIOQUIA-MEDELLIN                               136.093550
# COLEGIO MAYOR DE BOLIVAR-CARTAGENA                                 64.827121
# COLEGIO MAYOR DE NUESTRA SEÃORA DEL ROSARIO-BO...                154.166587
# COLEGIO MAYOR DEL CAUCA-POPAYAN                                   122.428387
# CONSERVATORIO DEL TOLIMA-IBAGUE                                   124.304717
# CORPORACION ACADEMIA SUPERIOR DE ARTES-MEDELLIN                     9.863889
# CORPORACION COLEGIATURA COLOMBIANA-MEDELLIN                       128.300799
# CORPORACION DE EDUCACION TECNOLOGICA COLSUBSIDI...                  9.712245
#
#                                                     punt_lectura_critica  \
# nombre_ies
# CENTRO DE EDUCACION MILITAR-BOGOTÃ D.C.                      125.753211
# COLEGIO DE ESTUDIOS SUPERIORES DE ADMINISTRACIO...            161.830191
# COLEGIO MAYOR DE ANTIOQUIA-MEDELLIN                           138.840590
# COLEGIO MAYOR DE BOLIVAR-CARTAGENA                             68.618915
# COLEGIO MAYOR DE NUESTRA SEÃORA DEL ROSARIO-BO...            164.401029
# COLEGIO MAYOR DEL CAUCA-POPAYAN                               121.660000
# CONSERVATORIO DEL TOLIMA-IBAGUE                               135.276887
# CORPORACION ACADEMIA SUPERIOR DE ARTES-MEDELLIN                10.314815
# CORPORACION COLEGIATURA COLOMBIANA-MEDELLIN                   137.410392
# CORPORACION DE EDUCACION TECNOLOGICA COLSUBSIDI...             10.025850
#
#                                                     punt_ingles  \
# nombre_ies
# CENTRO DE EDUCACION MILITAR-BOGOTÃ D.C.             137.469037
# COLEGIO DE ESTUDIOS SUPERIORES DE ADMINISTRACIO...   194.125583
# COLEGIO MAYOR DE ANTIOQUIA-MEDELLIN                  136.617670
# COLEGIO MAYOR DE BOLIVAR-CARTAGENA                    75.748192
# COLEGIO MAYOR DE NUESTRA SEÃORA DEL ROSARIO-BO...   183.149454
# COLEGIO MAYOR DEL CAUCA-POPAYAN                      123.670676
# CONSERVATORIO DEL TOLIMA-IBAGUE                      137.891274
# CORPORACION ACADEMIA SUPERIOR DE ARTES-MEDELLIN       10.463426
# CORPORACION COLEGIATURA COLOMBIANA-MEDELLIN          168.258833
# CORPORACION DE EDUCACION TECNOLOGICA COLSUBSIDI...    10.174694
#
#                                                     n_presentaciones  \
# nombre_ies
# CENTRO DE EDUCACION MILITAR-BOGOTÃ D.C.                         218
# COLEGIO DE ESTUDIOS SUPERIORES DE ADMINISTRACIO...              2196
# COLEGIO MAYOR DE ANTIOQUIA-MEDELLIN                             4713
# COLEGIO MAYOR DE BOLIVAR-CARTAGENA                               719
# COLEGIO MAYOR DE NUESTRA SEÃORA DEL ROSARIO-BO...             15943
# COLEGIO MAYOR DEL CAUCA-POPAYAN                                 2945
# CONSERVATORIO DEL TOLIMA-IBAGUE                                  424
# CORPORACION ACADEMIA SUPERIOR DE ARTES-MEDELLIN                  108
# CORPORACION COLEGIATURA COLOMBIANA-MEDELLIN                     1251
# CORPORACION DE EDUCACION TECNOLOGICA COLSUBSIDI...               147
#
#                                                     prop_p75_plus  \
# nombre_ies
# CENTRO DE EDUCACION MILITAR-BOGOTÃ D.C.                 0.366972
# COLEGIO DE ESTUDIOS SUPERIORES DE ADMINISTRACIO...       0.838798
# COLEGIO MAYOR DE ANTIOQUIA-MEDELLIN                      0.254615
# COLEGIO MAYOR DE BOLIVAR-CARTAGENA                       0.034771
# COLEGIO MAYOR DE NUESTRA SEÃORA DEL ROSARIO-BO...       0.747538
# COLEGIO MAYOR DEL CAUCA-POPAYAN                          0.096435
# CONSERVATORIO DEL TOLIMA-IBAGUE                          0.231132
# CORPORACION ACADEMIA SUPERIOR DE ARTES-MEDELLIN          0.000000
# CORPORACION COLEGIATURA COLOMBIANA-MEDELLIN              0.354916
# CORPORACION DE EDUCACION TECNOLOGICA COLSUBSIDI...       0.000000
#
#                                                     total_matriculados  \
# nombre_ies
# CENTRO DE EDUCACION MILITAR-BOGOTÃ D.C.                    639.800000
# COLEGIO DE ESTUDIOS SUPERIORES DE ADMINISTRACIO...         1752.000000
# COLEGIO MAYOR DE ANTIOQUIA-MEDELLIN                        4702.900000
# COLEGIO MAYOR DE BOLIVAR-CARTAGENA                         2287.800000
# COLEGIO MAYOR DE NUESTRA SEÃORA DEL ROSARIO-BO...        11760.818182
# COLEGIO MAYOR DEL CAUCA-POPAYAN                            2221.100000
# CONSERVATORIO DEL TOLIMA-IBAGUE                             382.200000
# CORPORACION ACADEMIA SUPERIOR DE ARTES-MEDELLIN             256.500000
# CORPORACION COLEGIATURA COLOMBIANA-MEDELLIN                 776.100000
# CORPORACION DE EDUCACION TECNOLOGICA COLSUBSIDI...          289.800000
#
#                                                     total_graduados  \
# nombre_ies
# CENTRO DE EDUCACION MILITAR-BOGOTÃ D.C.                 747.700000
# COLEGIO DE ESTUDIOS SUPERIORES DE ADMINISTRACIO...       507.500000
# COLEGIO MAYOR DE ANTIOQUIA-MEDELLIN                      746.700000
# COLEGIO MAYOR DE BOLIVAR-CARTAGENA                       641.800000
# COLEGIO MAYOR DE NUESTRA SEÃORA DEL ROSARIO-BO...      3426.454545
# COLEGIO MAYOR DEL CAUCA-POPAYAN                          532.200000
# CONSERVATORIO DEL TOLIMA-IBAGUE                           52.100000
# CORPORACION ACADEMIA SUPERIOR DE ARTES-MEDELLIN           49.400000
# CORPORACION COLEGIATURA COLOMBIANA-MEDELLIN              162.100000
# CORPORACION DE EDUCACION TECNOLOGICA COLSUBSIDI...        41.900000
#
#                                                     es_acreditada
# nombre_ies
# CENTRO DE EDUCACION MILITAR-BOGOTÃ D.C.                        0
# COLEGIO DE ESTUDIOS SUPERIORES DE ADMINISTRACIO...              1
# COLEGIO MAYOR DE ANTIOQUIA-MEDELLIN                             1
# COLEGIO MAYOR DE BOLIVAR-CARTAGENA                              0
# COLEGIO MAYOR DE NUESTRA SEÃORA DEL ROSARIO-BO...              1
# COLEGIO MAYOR DEL CAUCA-POPAYAN                                 0
# CONSERVATORIO DEL TOLIMA-IBAGUE                                 1
# CORPORACION ACADEMIA SUPERIOR DE ARTES-MEDELLIN                 0
# CORPORACION COLEGIATURA COLOMBIANA-MEDELLIN                     0
# CORPORACION DE EDUCACION TECNOLOGICA COLSUBSIDI...              0

# %% [markdown]
# ## 3. Analisis de Correlacion de Variables
# Analizamos como se correlacionan las 9 features a nivel de IES.
# Esto nos da una primera intuicion de por que el PCA podra reducir dimensiones:
# variables altamente correlacionadas seran capturadas por una misma componente principal.

# %% [markdown]
# ### Interpretación de la correlación de features
#
# - Los cuatro puntajes de Saber Pro (global, razonamiento cuantitativo, lectura crítica e inglés) están casi perfectamente correlacionados entre sí (correlaciones muy cercanas a 1), lo que indica que resumen una misma dimensión de desempeño académico promedio por IES.[Correlacion entre Features de IES (Saber Pro + SNIES)]
# - La proporción de estudiantes en el percentil 75 o superior también se asocia fuertemente con los puntajes (correlaciones alrededor de 0.7), por lo que funciona como un indicador compacto de alto rendimiento en cada institución.[Correlacion entre Features de IES (Saber Pro + SNIES)]
# - Las variables de escala institucional (total de matriculados y graduados) están fuertemente correlacionadas entre sí (cerca de 0.99), pero presentan correlaciones débiles e incluso negativas con los puntajes, sugiriendo que ser una IES grande no garantiza mejores resultados promedio en Saber Pro.[Correlacion entre Features de IES (Saber Pro + SNIES)]
# - La variable de acreditación institucional muestra correlaciones moderadas y positivas con puntajes y proporción P75+, pero mucho menores que las correlaciones entre puntajes, por lo que distingue en términos gruesos la calidad, sin capturar matices finos de desempeño.[Correlacion entre Features de IES (Saber Pro + SNIES)]
#
# <!-- AUTO_INTERPRETACION_correlacion -->

# %%
# Correlacion entre features
plt.figure(figsize=(10, 8))
sns.heatmap(features_ies.corr(), annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Correlacion entre Features de IES (Saber Pro + SNIES)', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Normalizacion y Analisis de Componentes Principales (ACP / PCA)
#
# **Paso critico:** Dado que las variables tienen diferentes escalas (puntajes ~150,
# matriculados ~10,000, binario 0/1), las normalizamos a media=0 y desviacion estandar=1.
#
# Luego aplicamos PCA para:
# 1. **Analizar** cuantas componentes explican >= 70% de la varianza total
# 2. **REDUCIR** las dimensiones de entrada al clustering a ese numero de componentes
#
# > **IMPORTANTE:** El clustering K-Means se entrena sobre las **componentes principales
# > reducidas**, NO sobre las 9 variables originales. Esto elimina multicolinealidad
# > y ruido de variables redundantes.

# %%
# Normalizar datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(features_ies)

# PCA COMPLETO para analizar la varianza de TODAS las componentes
pca_full = PCA()
pca_full.fit(X_scaled)

varianza_explicada = pca_full.explained_variance_ratio_
varianza_acumulada = np.cumsum(varianza_explicada)

print("Varianza explicada por cada Componente Principal:")
for i, var in enumerate(varianza_explicada):
    marker = " <-- " if varianza_acumulada[i] >= 0.70 and (i == 0 or varianza_acumulada[i-1] < 0.70) else ""
    print(f"  PC{i+1}: {var*100:.2f}% (Acumulada: {varianza_acumulada[i]*100:.2f}%){marker}")

# Determinar numero optimo de componentes (>= 70% varianza)
N_COMPONENTS = int(np.argmax(varianza_acumulada >= 0.70) + 1)
print(f"\n>>> Componentes necesarias para >= 70% varianza: {N_COMPONENTS}")
print(f">>> Reduccion de dimensiones: {X_scaled.shape[1]} variables -> {N_COMPONENTS} componentes principales")
# Out:
# Varianza explicada por cada Componente Principal:
#   PC1: 52.85% (Acumulada: 52.85%)
#   PC2: 26.22% (Acumulada: 79.07%) <--
#   PC3: 10.94% (Acumulada: 90.01%)
#   PC4: 6.36% (Acumulada: 96.38%)
#   PC5: 3.29% (Acumulada: 99.67%)
#   PC6: 0.14% (Acumulada: 99.81%)
#   PC7: 0.11% (Acumulada: 99.93%)
#   PC8: 0.07% (Acumulada: 100.00%)
#   PC9: 0.00% (Acumulada: 100.00%)
#
# >>> Componentes necesarias para >= 70% varianza: 2
# >>> Reduccion de dimensiones: 9 variables -> 2 componentes principales

# %% [markdown]
# ### Interpretación del PCA y varianza explicada
#
# - Las dos primeras componentes principales concentran aproximadamente 79 % de la varianza total (PC1 alrededor de 53 % y PC2 alrededor de 26 %), por lo que trabajar solo con ellas preserva la mayor parte de la información relevante de las 9 variables originales.
# - PC1 tiene cargas muy altas y positivas en los cuatro puntajes de Saber Pro y en la proporción de estudiantes en P75+, de modo que se interpreta naturalmente como un eje de "desempeño académico promedio / calidad" de las IES.
# - PC2 se carga de forma fuerte en el número de presentaciones, total de matriculados y total de graduados (cargas positivas altas), mientras que los puntajes pesan mucho menos, por lo que captura principalmente la dimensión de "escala / tamaño institucional" más que la de resultados.
# - La acreditación tiene cargas moderadas en ambas componentes, lo que indica que está relacionada tanto con mejor desempeño como con ciertas características de escala, pero sin dominar ninguna dimensión.
#
# <!-- AUTO_INTERPRETACION_pca -->

# %%
# Visualizar varianza explicada
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Barplot de varianza por componente
colors = ['#2196F3' if varianza_acumulada[i] < 0.70 else '#4CAF50' for i in range(len(varianza_explicada))]
axes[0].bar(range(1, len(varianza_explicada)+1), varianza_explicada, color=colors, edgecolor='black')
axes[0].set_xlabel('Componente Principal', fontsize=12)
axes[0].set_ylabel('Varianza Explicada', fontsize=12)
axes[0].set_title('Varianza Explicada por Componente', fontsize=13, fontweight='bold')
axes[0].set_xticks(range(1, len(varianza_explicada)+1))

# Lineplot de varianza acumulada
axes[1].plot(range(1, len(varianza_acumulada)+1), varianza_acumulada, 'ro-', linewidth=2, markersize=8)
axes[1].set_xlabel('Numero de Componentes', fontsize=12)
axes[1].set_ylabel('Varianza Explicada Acumulada', fontsize=12)
axes[1].set_title('Scree Plot (Varianza Acumulada)', fontsize=13, fontweight='bold')
axes[1].set_xticks(range(1, len(varianza_acumulada)+1))
axes[1].axhline(y=0.7, color='g', linestyle='--', label='Umbral 70% Varianza')
axes[1].axvline(x=N_COMPONENTS, color='orange', linestyle=':', lw=2, label=f'N={N_COMPONENTS} componentes')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# =====================================================================
# REDUCCION DE DIMENSIONES: Proyectar datos a N_COMPONENTS principales
# =====================================================================
# Este es el paso critico: K-Means se entrenara sobre X_pca_reduced,
# NO sobre X_scaled (que tiene 9 dimensiones con multicolinealidad)

pca = PCA(n_components=N_COMPONENTS, random_state=42)
X_pca_reduced = pca.fit_transform(X_scaled)

print(f"Matriz de entrada al clustering:")
print(f"  Antes (X_scaled):       {X_scaled.shape[0]} IES x {X_scaled.shape[1]} variables")
print(f"  Despues (X_pca_reduced): {X_pca_reduced.shape[0]} IES x {X_pca_reduced.shape[1]} componentes")
print(f"  Varianza retenida: {pca.explained_variance_ratio_.sum()*100:.1f}%")

# Mostrar tabla de loadings (contribucion de cada variable a cada PC)
loadings_df = pd.DataFrame(
    pca.components_.T,
    index=features_ies.columns,
    columns=[f'PC{i+1}' for i in range(N_COMPONENTS)]
)
print(f"\nLoadings (contribucion de cada variable a cada componente):")
display(loadings_df.style.background_gradient(cmap='RdBu_r', vmin=-1, vmax=1).format('{:.3f}'))
# Out:
# Matriz de entrada al clustering:
#   Antes (X_scaled):       336 IES x 9 variables
#   Despues (X_pca_reduced): 336 IES x 2 componentes
#   Varianza retenida: 79.1%
#
# Loadings (contribucion de cada variable a cada componente):
# <style type="text/css">
# #T_61318_row0_col0, #T_61318_row1_col0, #T_61318_row2_col0, #T_61318_row3_col0 {
#   background-color: #ec9374;
#   color: #f1f1f1;
# }
# #T_61318_row0_col1, #T_61318_row2_col1, #T_61318_row3_col1 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_61318_row1_col1 {
#   background-color: #f7f5f4;
#   color: #000000;
# }
# #T_61318_row4_col0 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_61318_row4_col1 {
#   background-color: #e98b6e;
#   color: #f1f1f1;
# }
# #T_61318_row5_col0 {
#   background-color: #f6af8e;
#   color: #000000;
# }
# #T_61318_row5_col1 {
#   background-color: #faeae1;
#   color: #000000;
# }
# #T_61318_row6_col0, #T_61318_row7_col0 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_61318_row6_col1, #T_61318_row7_col1 {
#   background-color: #d55d4c;
#   color: #f1f1f1;
# }
# #T_61318_row8_col0, #T_61318_row8_col1 {
#   background-color: #fcdfcf;
#   color: #000000;
# }
# </style>
# <table id="T_61318">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61318_level0_col0" class="col_heading level0 col0" >PC1</th>
#       <th id="T_61318_level0_col1" class="col_heading level0 col1" >PC2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61318_level0_row0" class="row_heading level0 row0" >puntaje_global</th>
#       <td id="T_61318_row0_col0" class="data row0 col0" >0.450</td>
#       <td id="T_61318_row0_col1" class="data row0 col1" >0.006</td>
#     </tr>
#     <tr>
#       <th id="T_61318_level0_row1" class="row_heading level0 row1" >punt_razona_cuantitativa</th>
#       <td id="T_61318_row1_col0" class="data row1 col0" >0.450</td>
#       <td id="T_61318_row1_col1" class="data row1 col1" >0.009</td>
#     </tr>
#     <tr>
#       <th id="T_61318_level0_row2" class="row_heading level0 row2" >punt_lectura_critica</th>
#       <td id="T_61318_row2_col0" class="data row2 col0" >0.449</td>
#       <td id="T_61318_row2_col1" class="data row2 col1" >0.007</td>
#     </tr>
#     <tr>
#       <th id="T_61318_level0_row3" class="row_heading level0 row3" >punt_ingles</th>
#       <td id="T_61318_row3_col0" class="data row3 col0" >0.451</td>
#       <td id="T_61318_row3_col1" class="data row3 col1" >0.006</td>
#     </tr>
#     <tr>
#       <th id="T_61318_level0_row4" class="row_heading level0 row4" >n_presentaciones</th>
#       <td id="T_61318_row4_col0" class="data row4 col0" >0.101</td>
#       <td id="T_61318_row4_col1" class="data row4 col1" >0.474</td>
#     </tr>
#     <tr>
#       <th id="T_61318_level0_row5" class="row_heading level0 row5" >prop_p75_plus</th>
#       <td id="T_61318_row5_col0" class="data row5 col0" >0.364</td>
#       <td id="T_61318_row5_col1" class="data row5 col1" >0.088</td>
#     </tr>
#     <tr>
#       <th id="T_61318_level0_row6" class="row_heading level0 row6" >total_matriculados</th>
#       <td id="T_61318_row6_col0" class="data row6 col0" >-0.099</td>
#       <td id="T_61318_row6_col1" class="data row6 col1" >0.609</td>
#     </tr>
#     <tr>
#       <th id="T_61318_level0_row7" class="row_heading level0 row7" >total_graduados</th>
#       <td id="T_61318_row7_col0" class="data row7 col0" >-0.097</td>
#       <td id="T_61318_row7_col1" class="data row7 col1" >0.608</td>
#     </tr>
#     <tr>
#       <th id="T_61318_level0_row8" class="row_heading level0 row8" >es_acreditada</th>
#       <td id="T_61318_row8_col0" class="data row8 col0" >0.168</td>
#       <td id="T_61318_row8_col1" class="data row8 col1" >0.164</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 5. Seleccion del Numero Optimo de Clusters (K)
# Probamos K de 2 a 10 usando **las componentes principales reducidas** (no las variables
# originales). Evaluamos con Inercia (WCSS), Silhouette Score y Davies-Bouldin Index.

# %%
# Probar diferentes valores de K sobre X_pca_reduced
K_range = range(2, 11)
inertias = []
silhouette_scores = []
davies_bouldin_scores = []

print("Calculando metricas para K = 2 a 10 (sobre componentes PCA reducidas)...")

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(X_pca_reduced)  # <-- SOBRE PCA REDUCIDO

    inertias.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(X_pca_reduced, labels))
    davies_bouldin_scores.append(davies_bouldin_score(X_pca_reduced, labels))

# Tabla resumen
df_metrics = pd.DataFrame({
    'K': list(K_range),
    'Inercia': inertias,
    'Silhouette': silhouette_scores,
    'Davies-Bouldin': davies_bouldin_scores
}).set_index('K')

print("\nResumen de metricas por K:")
display(df_metrics.style.highlight_max(subset=['Silhouette'], color='lightgreen')
                        .highlight_min(subset=['Davies-Bouldin'], color='lightyellow')
                        .format('{:.3f}'))
# Out:
# Calculando metricas para K = 2 a 10 (sobre componentes PCA reducidas)...
#
# Resumen de metricas por K:
# <style type="text/css">
# #T_9edce_row0_col1 {
#   background-color: lightgreen;
# }
# #T_9edce_row1_col2 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_9edce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9edce_level0_col0" class="col_heading level0 col0" >Inercia</th>
#       <th id="T_9edce_level0_col1" class="col_heading level0 col1" >Silhouette</th>
#       <th id="T_9edce_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >K</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9edce_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_9edce_row0_col0" class="data row0 col0" >1139.383</td>
#       <td id="T_9edce_row0_col1" class="data row0 col1" >0.675</td>
#       <td id="T_9edce_row0_col2" class="data row0 col2" >0.554</td>
#     </tr>
#     <tr>
#       <th id="T_9edce_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_9edce_row1_col0" class="data row1 col0" >594.123</td>
#       <td id="T_9edce_row1_col1" class="data row1 col1" >0.675</td>
#       <td id="T_9edce_row1_col2" class="data row1 col2" >0.367</td>
#     </tr>
#     <tr>
#       <th id="T_9edce_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_9edce_row2_col0" class="data row2 col0" >373.046</td>
#       <td id="T_9edce_row2_col1" class="data row2 col1" >0.494</td>
#       <td id="T_9edce_row2_col2" class="data row2 col2" >0.577</td>
#     </tr>
#     <tr>
#       <th id="T_9edce_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_9edce_row3_col0" class="data row3 col0" >295.665</td>
#       <td id="T_9edce_row3_col1" class="data row3 col1" >0.497</td>
#       <td id="T_9edce_row3_col2" class="data row3 col2" >0.570</td>
#     </tr>
#     <tr>
#       <th id="T_9edce_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_9edce_row4_col0" class="data row4 col0" >228.831</td>
#       <td id="T_9edce_row4_col1" class="data row4 col1" >0.477</td>
#       <td id="T_9edce_row4_col2" class="data row4 col2" >0.612</td>
#     </tr>
#     <tr>
#       <th id="T_9edce_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_9edce_row5_col0" class="data row5 col0" >176.191</td>
#       <td id="T_9edce_row5_col1" class="data row5 col1" >0.463</td>
#       <td id="T_9edce_row5_col2" class="data row5 col2" >0.633</td>
#     </tr>
#     <tr>
#       <th id="T_9edce_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_9edce_row6_col0" class="data row6 col0" >146.111</td>
#       <td id="T_9edce_row6_col1" class="data row6 col1" >0.433</td>
#       <td id="T_9edce_row6_col2" class="data row6 col2" >0.655</td>
#     </tr>
#     <tr>
#       <th id="T_9edce_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_9edce_row7_col0" class="data row7 col0" >124.721</td>
#       <td id="T_9edce_row7_col1" class="data row7 col1" >0.457</td>
#       <td id="T_9edce_row7_col2" class="data row7 col2" >0.637</td>
#     </tr>
#     <tr>
#       <th id="T_9edce_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_9edce_row8_col0" class="data row8 col0" >105.457</td>
#       <td id="T_9edce_row8_col1" class="data row8 col1" >0.462</td>
#       <td id="T_9edce_row8_col2" class="data row8 col2" >0.601</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Interpretación de la selección del número de clusters
#
# - El método del codo muestra una reducción fuerte de la inercia al pasar de K=2 a K=3, pero después las mejoras marginales son cada vez menores, lo que sugiere un número de clusters pequeño como razonable para este espacio PCA de 2 dimensiones.
# - El Silhouette Score alcanza valores altos alrededor de K en el rango 2 a 3 (cerca de 0.67), lo que indica que, con pocos clusters, las IES quedan bien separadas entre grupos y con baja superposición entre fronteras de decisión.
# - El índice de Davies-Bouldin también es relativamente bajo para esos valores de K, reforzando que las soluciones con pocos clusters producen grupos compactos y bien separados en el plano de componentes principales.
# - Dado que K=2 maximiza el Silhouette y permite una interpretación clara (un grupo de desempeño crítico frente a uno de desempeño medio/alto), se adopta esta configuración como modelo final de clustering.

# %%
# Visualizar metodo del codo y silhouette
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Metodo del codo
axes[0].plot(K_range, inertias, 'bo-', linewidth=2, markersize=8)
axes[0].set_xlabel('Numero de Clusters (K)', fontsize=12)
axes[0].set_ylabel('Inercia (WCSS)', fontsize=12)
axes[0].set_title('Metodo del Codo', fontsize=13, fontweight='bold')
axes[0].set_xticks(K_range)

# Silhouette Score
axes[1].plot(K_range, silhouette_scores, 'ro-', linewidth=2, markersize=8)
axes[1].set_xlabel('Numero de Clusters (K)', fontsize=12)
axes[1].set_ylabel('Silhouette Score', fontsize=12)
axes[1].set_title('Silhouette Score', fontsize=13, fontweight='bold')
axes[1].set_xticks(K_range)

# Davies-Bouldin Index
axes[2].plot(K_range, davies_bouldin_scores, 'go-', linewidth=2, markersize=8)
axes[2].set_xlabel('Numero de Clusters (K)', fontsize=12)
axes[2].set_ylabel('Davies-Bouldin Index', fontsize=12)
axes[2].set_title('Davies-Bouldin (menor = mejor)', fontsize=13, fontweight='bold')
axes[2].set_xticks(K_range)

plt.suptitle('Seleccion de K sobre Componentes PCA Reducidas', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Entrenamiento del Modelo Final (K-Means sobre PCA Reducido)
# Entrenamos el modelo con el K optimo (seleccionado por Silhouette Score maximo)
# sobre las **componentes principales reducidas**.

# %%
# Seleccionar K optimo basado en Silhouette Score maximo
K_OPTIMO = list(K_range)[np.argmax(silhouette_scores)]
print(f"K optimo seleccionado: {K_OPTIMO} (Silhouette: {max(silhouette_scores):.3f})")

# Entrenar K-Means SOBRE PCA REDUCIDO
kmeans_final = KMeans(n_clusters=K_OPTIMO, random_state=42, n_init=20)
labels_final = kmeans_final.fit_predict(X_pca_reduced)  # <-- SOBRE PCA REDUCIDO

# Agregar la etiqueta del cluster al dataframe original
features_ies['cluster'] = labels_final

# Metricas de calidad
silh_final = silhouette_score(X_pca_reduced, labels_final)
db_final = davies_bouldin_score(X_pca_reduced, labels_final)
ch_final = calinski_harabasz_score(X_pca_reduced, labels_final)

print(f"\nMetricas del modelo de K={K_OPTIMO} clusters (sobre {N_COMPONENTS} componentes PCA):")
print(f"  Silhouette Score:        {silh_final:.3f}")
print(f"  Davies-Bouldin Index:    {db_final:.3f}")
print(f"  Calinski-Harabasz Score: {ch_final:.1f}")

print(f"\nDistribucion de IES por cluster:")
print(features_ies['cluster'].value_counts().sort_index())
# Out:
# K optimo seleccionado: 2 (Silhouette: 0.675)
#
# Metricas del modelo de K=2 clusters (sobre 2 componentes PCA):
#   Silhouette Score:        0.675
#   Davies-Bouldin Index:    0.554
#   Calinski-Harabasz Score: 367.0
#
# Distribucion de IES por cluster:
# cluster
# 0    267
# 1     69
# Name: count, dtype: int64

# %% [markdown]
# ### Interpretación del modelo final de clustering (K=2)
#
# - Con K=2 y 2 componentes principales como entrada, el modelo agrupa 336 IES en dos clusters de tamaños muy desbalanceados: un cluster mayoritario con 267 instituciones y otro minoritario con 69 instituciones.
# - El Silhouette global de aproximadamente 0.675 y un Davies-Bouldin cercano a 0.55 indican una separación bastante nítida entre los dos grupos en el espacio PCA, con poca ambigüedad en la asignación de IES a cada cluster.
# - El cluster con mayor tamaño concentra IES con puntajes globales y disciplinares notablemente superiores, mientras que el cluster pequeño agrupa instituciones con puntajes promedio extremadamente bajos, lo que motiva etiquetarlo como grupo de "desempeño crítico".
# - Estos resultados sugieren que, en el periodo analizado, existe una segmentación fuerte del sistema de educación superior entre un subconjunto de IES con desempeño muy bajo y el resto con niveles de rendimiento sustancialmente mejores.

# %% [markdown]
# ## 7. Visualizacion del Espacio PCA y Biplot
# Graficamos la proyeccion de las IES en el plano PC1 vs PC2 y superponemos los
# vectores de carga de cada variable original (Biplot) para entender que variables
# determinan la formacion de los clusters.
#
# > Las IES estan coloreadas por su cluster asignado (entrenado sobre las dimensiones
# > PCA reducidas, no sobre las variables originales).

# %%
# === BIPLOT PCA y Clusters de IES ===
# Siempre usamos las 2 primeras componentes para la visualizacion
X_pca_2d = X_pca_reduced[:, :2] if X_pca_reduced.shape[1] >= 2 else pca.transform(X_scaled)[:, :2]

fig, ax = plt.subplots(figsize=(14, 10))

# Scatter de IES en espacio PCA coloreado por Cluster
scatter = ax.scatter(X_pca_2d[:, 0], X_pca_2d[:, 1], c=labels_final,
                     cmap='viridis', alpha=0.6, s=90, edgecolors='k')

# Obtener loadings (direccion y magnitud de variables originales en PCA)
loadings = pca.components_.T
feature_names_pca = features_ies.drop(columns=['cluster'], errors='ignore').columns.tolist()

# Escalar flechas
scale = np.abs(X_pca_2d).max() * 0.8

for j, fname in enumerate(feature_names_pca):
    ax.annotate('',
        xy=(loadings[j, 0] * scale, loadings[j, 1] * scale),
        xytext=(0, 0),
        arrowprops=dict(arrowstyle='->', color='red', lw=2.5)
    )
    # Etiqueta de la variable
    ax.text(loadings[j, 0] * scale * 1.15,
            loadings[j, 1] * scale * 1.15,
            fname.replace('_', ' ').title(),
            fontsize=9, fontweight='bold', color='darkred',
            ha='center', va='center',
            bbox=dict(boxstyle='round,pad=0.3', facecolor='lightyellow', alpha=0.8))

# Circulo unitario de referencia
circle = plt.Circle((0, 0), scale, fill=False, color='gray', linestyle='--', lw=1)
ax.add_patch(circle)

ax.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% varianza)', fontsize=12)
ax.set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% varianza)', fontsize=12)
ax.set_title(f'Biplot PCA: Clusters de IES (K={K_OPTIMO}, {N_COMPONENTS} componentes, {pca.explained_variance_ratio_.sum()*100:.0f}% varianza)',
             fontsize=14, fontweight='bold')
ax.axhline(y=0, color='gray', linestyle='-', lw=0.5)
ax.axvline(x=0, color='gray', linestyle='-', lw=0.5)
ax.grid(True, alpha=0.3)

# Leyenda
handles, _ = scatter.legend_elements()
legend_labels = [f'Cluster {i}' for i in range(len(handles))]
ax.legend(handles, legend_labels, title='Clusters', loc='best')

plt.tight_layout()
plt.savefig(ARTIFACTS_DIR / 'visualizaciones' / f'clusters_ies_pca_biplot_{datetime.now().strftime("%Y%m%d")}.png',
            dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Interpretación del biplot PCA con clusters de IES
#
# - En el plano PC1–PC2, el eje horizontal (PC1) organiza a las IES desde instituciones con puntajes promedio muy bajos hacia instituciones con puntajes y proporción en P75+ altos, reflejando un gradiente claro de calidad académica.
# - El eje vertical (PC2) separa principalmente por escala: IES con muchos matriculados, graduados y presentaciones aparecen en la parte superior, mientras que instituciones más pequeñas se ubican en la parte inferior del plano.
# - Los vectores de carga muestran que los cuatro puntajes y la proporción P75+ apuntan en direcciones muy similares, reforzando que son indicadores redundantes de una misma dimensión de desempeño académico.
# - Los clusters aparecen bien separados: el grupo de desempeño crítico se concentra en la región de PC1 muy negativa, mientras que el cluster de mejor desempeño se distribuye hacia valores de PC1 positivos, lo que facilita interpretar cada cluster en función de la combinación de calidad y tamaño.
#
# <!-- AUTO_INTERPRETACION_biplot -->

# %% [markdown]
# ## 8. Analisis de Perfiles por Cluster
# Calculamos las medianas (y estadísticas robustas) de cada variable ORIGINAL en cada cluster.
# Usamos la mediana en lugar de la media para evitar que valores extremos en puntajes por IES distorsionen la comparación.
# Esto nos permite interpretar de forma más robusta qué caracteriza a cada grupo de IES.

# %%
# Calcular perfiles (medianas y estadistica robusta de variables originales)
# Usamos la mediana por cluster para evitar la influencia de outliers en variables de escala disimil.
perfiles = features_ies.groupby('cluster').agg({
    'puntaje_global': ['median', 'std', 'count'],
    'punt_razona_cuantitativa': 'median',
    'punt_lectura_critica': 'median',
    'punt_ingles': 'median',
    'prop_p75_plus': 'median',
    'n_presentaciones': ['sum', 'median'],
    'total_matriculados': ['sum', 'median'],
    'total_graduados': ['sum', 'median'],
    'es_acreditada': 'median'
})

# Normalizar nombres de columnas y redondear
perfiles.columns = ['_'.join(col).strip() for col in perfiles.columns.values]
perfiles = perfiles.round(2)

print("\nResumen de Perfiles por Cluster (medianas de variables originales):")
display(perfiles)

# Guardar perfiles robustos
perfiles.to_csv(ARTIFACTS_DIR / 'metricas' / f'perfiles_clusters_median_{datetime.now().strftime("%Y%m%d")}.csv')
# Out:
# Resumen de Perfiles por Cluster (medianas de variables originales):
#          puntaje_global_median  puntaje_global_std  puntaje_global_count  \
# cluster
# 0                       131.11               14.73                   267
# 1                        10.03               24.70                    69
#
#          punt_razona_cuantitativa_median  punt_lectura_critica_median  \
# cluster
# 0                                 129.81                       134.03
# 1                                   9.93                        10.24
#
#          punt_ingles_median  prop_p75_plus_median  n_presentaciones_sum  \
# cluster
# 0                    136.32                  0.19               2472798
# 1                     10.06                  0.00                176066
#
#          n_presentaciones_median  total_matriculados_sum  \
# cluster
# 0                         5409.0              1959044.62
# 1                          296.0              1513074.45
#
#          total_matriculados_median  total_graduados_sum  \
# cluster
# 0                          3878.08            388934.44
# 1                          3878.08            286936.59
#
#          total_graduados_median  es_acreditada_median
# cluster
# 0                         808.4                   0.0
# 1                         805.9                   0.0

# %%
# Definiciones para plotting de perfiles (robusto)
# Consolidamos la preparacion y visualizacion en la siguiente celda para limpieza visual
pass

# %%
# Visualizacion de perfiles de cluster (medianas de variables originales)
features_to_plot = [
    'puntaje_global', 'punt_razona_cuantitativa', 'punt_lectura_critica', 'punt_ingles',
    'prop_p75_plus', 'n_presentaciones', 'total_matriculados', 'total_graduados', 'es_acreditada'
]

# Definir una paleta de colores premium y con alto contraste para los clusters:
# Cluster 0: Azul cielo premium (#4EA8DE), Cluster 1: Naranja Coral/Fuego (#F77F00) representativo del cluster critico
cluster_colors = ['#4EA8DE', '#F77F00', '#4CAF50', '#FFC107', '#9C27B0']
colors_to_use = cluster_colors[:int(K_OPTIMO)] if int(K_OPTIMO) <= len(cluster_colors) else sns.color_palette('Set2', n_colors=int(K_OPTIMO))

fig, axes = plt.subplots(3, 3, figsize=(18, 15))
axes = axes.ravel()

for idx, feat in enumerate(features_to_plot):
    # Agrupamos por cluster y calculamos la mediana
    cluster_stat = features_ies.groupby('cluster')[feat].median()
    
    bars = axes[idx].bar(cluster_stat.index.astype(str), cluster_stat.values,
                         color=colors_to_use, edgecolor='black', width=0.55)
    
    # Formateo visual premium
    axes[idx].set_xlabel('Cluster', fontsize=11, fontweight='bold', labelpad=4)
    axes[idx].set_ylabel(f'Mediana de {feat.replace("_", " ").title()}', fontsize=10, fontweight='bold')
    axes[idx].set_title(f'{feat.replace("_", " ").title()}', fontsize=13, fontweight='bold', pad=10)
    axes[idx].grid(axis='y', linestyle='--', alpha=0.4)
    axes[idx].set_xticks(range(int(K_OPTIMO)))
    axes[idx].set_xticklabels([f'Cluster {i}' for i in range(int(K_OPTIMO))], fontsize=10)
    
    # Ajustar limites superiores para que las etiquetas tengan espacio
    y_max = cluster_stat.max()
    if y_max > 0:
        axes[idx].set_ylim(0, y_max * 1.18)
    
    # Agregar etiquetas con los valores exactos encima de cada barra
    for bar in bars:
        height = bar.get_height()
        # Dar formato segun el rango numerico
        if height >= 1000:
            label_text = f'{height:,.0f}'
        elif height >= 100:
            label_text = f'{height:,.1f}'
        elif height >= 1:
            label_text = f'{height:,.2f}'
        else:
            label_text = f'{height:.3f}'
            
        axes[idx].annotate(label_text,
                           xy=(bar.get_x() + bar.get_width() / 2, height),
                           xytext=(0, 4),  # 4 points vertical offset
                           textcoords="offset points",
                           ha='center', va='bottom', fontsize=9.5, fontweight='bold',
                           bbox=dict(boxstyle='round,pad=0.2', facecolor='white', edgecolor='gray', alpha=0.8, lw=0.5))

plt.suptitle(f'Perfiles Robustos de {K_OPTIMO} Clusters (Medianas de Variables Originales)', 
             fontsize=17, fontweight='bold', y=1.02)
plt.tight_layout()

# Guardamos con ambos nombres para asegurar compatibilidad total en reportes y entregas
plt.savefig(ARTIFACTS_DIR / 'visualizaciones' / 'perfiles_clusters_barplot_median.png', dpi=150, bbox_inches='tight')
plt.savefig(ARTIFACTS_DIR / 'visualizaciones' / 'perfiles_clusters_barplot.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Interpretación de los perfiles (medianas) de cada cluster
#
# - Los perfiles se calculan aquí mediante la mediana para evitar que instituciones con valores extremos en puntajes alteren la comparación entre clusters.
# - El cluster identificado como de mejor desempeño muestra medianas de puntaje sustancialmente más altas que el cluster crítico, evidenciando una brecha robusta de rendimiento entre grupos de IES.
# - Asimismo, la mediana de la proporción de estudiantes en el percentil 75+ es mayor en el cluster de mejor desempeño, lo que indica mayor concentración de estudiantes con resultados sobresalientes.
# - El cluster crítico agrupa IES con medianas de puntaje global y disciplinares notablemente bajas, y presenta heterogeneidad en tamaños institucionales; esto sugiere que el bajo rendimiento es un fenómeno que atraviesa distintos tipos de IES.
# - La mediana de acreditación es superior en el cluster de mejor desempeño, lo que es coherente con una asociación entre acreditación y mejores resultados, aunque no explica toda la variabilidad observada.
#
# <!-- AUTO_INTERPRETACION_perfiles -->

# %% [markdown]
# ## 9. Auditoria del Cluster de Desempeno Critico
# Investigamos si los valores bajos del cluster de desempeno critico representan
# anomalias de datos o el comportamiento real de ciertas instituciones.

# %%
# Identificar el cluster con peor puntaje promedio
cluster_worst = features_ies.groupby('cluster')['puntaje_global'].median().idxmin()
cluster_worst_df = features_ies[features_ies['cluster'] == cluster_worst].copy()

print('='*70)
print(f'AUDITORIA DETALLADA: CLUSTER {cluster_worst} (DESEMPENO CRITICO)')
print('='*70)
print(f'Total de IES en Cluster {cluster_worst}: {len(cluster_worst_df)}')
print(f'Estadisticas del puntaje global en el Cluster {cluster_worst}:')
print(cluster_worst_df['puntaje_global'].describe())

print(f'\n--- IES con puntaje MAS BAJO (Top 10) ---')
display(cluster_worst_df.nsmallest(10, 'puntaje_global')[
    ['puntaje_global', 'punt_lectura_critica', 'punt_ingles', 'n_presentaciones', 'total_matriculados', 'es_acreditada']])

print(f'\n--- IES con puntaje MAS ALTO del Cluster {cluster_worst} (Top 5) ---')
display(cluster_worst_df.nlargest(5, 'puntaje_global')[
    ['puntaje_global', 'punt_lectura_critica', 'punt_ingles', 'n_presentaciones', 'total_matriculados', 'es_acreditada']])
# Out:
# ======================================================================
# AUDITORIA DETALLADA: CLUSTER 1 (DESEMPENO CRITICO)
# ======================================================================
# Total de IES en Cluster 1: 69
# Estadisticas del puntaje global en el Cluster 1:
# count    69.000000
# mean     25.076196
# std      24.704018
# min       9.321961
# 25%       9.794354
# 50%      10.026282
# 75%      42.337917
# max      79.725000
# Name: puntaje_global, dtype: float64
#
# --- IES con puntaje MAS BAJO (Top 10) ---
#                                                     puntaje_global  \
# nombre_ies
# UNIVERSIDAD DE LA GUAJIRA                                 9.321961
# ESCUELA  MILITAR DE SUBOFICIALES SARGENTO INOCE...        9.327950
# UNIVERSIDAD DEL MAGDALENA                                 9.354424
# CORPORACION UNIVERSITARIA DEL CARIBE                      9.475605
# UNIVERSIDAD DE CORDOBA                                    9.506694
# ESCUELA DE FORMACION DE INFANTERIA DE MARINA              9.516848
# UNIVERSIDAD DE CARTAGENA                                  9.580018
# UNIVERSIDAD DE PAMPLONA                                   9.597095
# CORPORACION UNIVERSITARIA REGIONAL DEL CARIBE -...        9.598745
# FUNDACION UNIVERSITARIA LUIS AMIGO FUNLAM                 9.621019
#
#                                                     punt_lectura_critica  \
# nombre_ies
# UNIVERSIDAD DE LA GUAJIRA                                       9.528682
# ESCUELA  MILITAR DE SUBOFICIALES SARGENTO INOCE...              9.232158
# UNIVERSIDAD DEL MAGDALENA                                       9.622469
# CORPORACION UNIVERSITARIA DEL CARIBE                            9.667516
# UNIVERSIDAD DE CORDOBA                                          9.766204
# ESCUELA DE FORMACION DE INFANTERIA DE MARINA                    9.472121
# UNIVERSIDAD DE CARTAGENA                                        9.810494
# UNIVERSIDAD DE PAMPLONA                                         9.798510
# CORPORACION UNIVERSITARIA REGIONAL DEL CARIBE -...              9.647205
# FUNDACION UNIVERSITARIA LUIS AMIGO FUNLAM                       9.849686
#
#                                                     punt_ingles  \
# nombre_ies
# UNIVERSIDAD DE LA GUAJIRA                              9.445039
# ESCUELA  MILITAR DE SUBOFICIALES SARGENTO INOCE...     9.540426
# UNIVERSIDAD DEL MAGDALENA                              9.368938
# CORPORACION UNIVERSITARIA DEL CARIBE                   9.566560
# UNIVERSIDAD DE CORDOBA                                 9.586065
# ESCUELA DE FORMACION DE INFANTERIA DE MARINA           9.558667
# UNIVERSIDAD DE CARTAGENA                               9.571102
# UNIVERSIDAD DE PAMPLONA                                9.569190
# CORPORACION UNIVERSITARIA REGIONAL DEL CARIBE -...     9.406832
# FUNDACION UNIVERSITARIA LUIS AMIGO FUNLAM              9.583710
#
#                                                     n_presentaciones  \
# nombre_ies
# UNIVERSIDAD DE LA GUAJIRA                                        129
# ESCUELA  MILITAR DE SUBOFICIALES SARGENTO INOCE...              1219
# UNIVERSIDAD DEL MAGDALENA                                        810
# CORPORACION UNIVERSITARIA DEL CARIBE                             157
# UNIVERSIDAD DE CORDOBA                                           216
# ESCUELA DE FORMACION DE INFANTERIA DE MARINA                     165
# UNIVERSIDAD DE CARTAGENA                                        1315
# UNIVERSIDAD DE PAMPLONA                                         1074
# CORPORACION UNIVERSITARIA REGIONAL DEL CARIBE -...               161
# FUNDACION UNIVERSITARIA LUIS AMIGO FUNLAM                        159
#
#                                                     total_matriculados  \
# nombre_ies
# UNIVERSIDAD DE LA GUAJIRA                                 14394.400000
# ESCUELA  MILITAR DE SUBOFICIALES SARGENTO INOCE...         4477.636364
# UNIVERSIDAD DEL MAGDALENA                                 22132.500000
# CORPORACION UNIVERSITARIA DEL CARIBE                       9793.000000
# UNIVERSIDAD DE CORDOBA                                    15704.000000
# ESCUELA DE FORMACION DE INFANTERIA DE MARINA                282.800000
# UNIVERSIDAD DE CARTAGENA                                  20194.000000
# UNIVERSIDAD DE PAMPLONA                                   23834.400000
# CORPORACION UNIVERSITARIA REGIONAL DEL CARIBE -...          228.285714
# FUNDACION UNIVERSITARIA LUIS AMIGO FUNLAM                 14557.454545
#
#                                                     es_acreditada
# nombre_ies
# UNIVERSIDAD DE LA GUAJIRA                                       1
# ESCUELA  MILITAR DE SUBOFICIALES SARGENTO INOCE...              0
# UNIVERSIDAD DEL MAGDALENA                                       1
# CORPORACION UNIVERSITARIA DEL CARIBE                            0
# UNIVERSIDAD DE CORDOBA                                          1
# ESCUELA DE FORMACION DE INFANTERIA DE MARINA                    1
# UNIVERSIDAD DE CARTAGENA                                        1
# UNIVERSIDAD DE PAMPLONA                                         1
# CORPORACION UNIVERSITARIA REGIONAL DEL CARIBE -...              0
# FUNDACION UNIVERSITARIA LUIS AMIGO FUNLAM                       0
# --- IES con puntaje MAS ALTO del Cluster 1 (Top 5) ---
#                                                     puntaje_global  \
# nombre_ies
# ESCUELA DE COMUNICACIONES-FACATATIVA                     79.725000
# IE ESCUELA NORMAL SUPERIOR DE BUCARAMANGA SEDE ...       78.205416
# ESCUELA NORMAL SUPERIOR LACIDES IRIARTE-SAHAGUN          77.091549
# CORPORACION INTERNACIONAL PARA EL DESARROLLO ED...       76.862495
# ESCUELA NORMAL SAN PEDRO ALEJANDRINO-SANTA MARTA         74.600949
#
#                                                     punt_lectura_critica  \
# nombre_ies
# ESCUELA DE COMUNICACIONES-FACATATIVA                           76.643210
# IE ESCUELA NORMAL SUPERIOR DE BUCARAMANGA SEDE ...             77.334122
# ESCUELA NORMAL SUPERIOR LACIDES IRIARTE-SAHAGUN                76.212676
# CORPORACION INTERNACIONAL PARA EL DESARROLLO ED...             77.754967
# ESCUELA NORMAL SAN PEDRO ALEJANDRINO-SANTA MARTA               74.310185
#
#                                                     punt_ingles  \
# nombre_ies
# ESCUELA DE COMUNICACIONES-FACATATIVA                  84.788518
# IE ESCUELA NORMAL SUPERIOR DE BUCARAMANGA SEDE ...    78.614358
# ESCUELA NORMAL SUPERIOR LACIDES IRIARTE-SAHAGUN       75.409859
# CORPORACION INTERNACIONAL PARA EL DESARROLLO ED...    80.178305
# ESCUELA NORMAL SAN PEDRO ALEJANDRINO-SANTA MARTA      72.857685
#
#                                                     n_presentaciones  \
# nombre_ies
# ESCUELA DE COMUNICACIONES-FACATATIVA                             162
# IE ESCUELA NORMAL SUPERIOR DE BUCARAMANGA SEDE ...               296
# ESCUELA NORMAL SUPERIOR LACIDES IRIARTE-SAHAGUN                  142
# CORPORACION INTERNACIONAL PARA EL DESARROLLO ED...               755
# ESCUELA NORMAL SAN PEDRO ALEJANDRINO-SANTA MARTA                 108
#
#                                                     total_matriculados  \
# nombre_ies
# ESCUELA DE COMUNICACIONES-FACATATIVA                        254.500000
# IE ESCUELA NORMAL SUPERIOR DE BUCARAMANGA SEDE ...         3878.077273
# ESCUELA NORMAL SUPERIOR LACIDES IRIARTE-SAHAGUN            3878.077273
# CORPORACION INTERNACIONAL PARA EL DESARROLLO ED...          786.181818
# ESCUELA NORMAL SAN PEDRO ALEJANDRINO-SANTA MARTA           3878.077273
#
#                                                     es_acreditada
# nombre_ies
# ESCUELA DE COMUNICACIONES-FACATATIVA                            0
# IE ESCUELA NORMAL SUPERIOR DE BUCARAMANGA SEDE ...              0
# ESCUELA NORMAL SUPERIOR LACIDES IRIARTE-SAHAGUN                 0
# CORPORACION INTERNACIONAL PARA EL DESARROLLO ED...              0
# ESCUELA NORMAL SAN PEDRO ALEJANDRINO-SANTA MARTA                0

# %% [markdown]
# ### Interpretación de la auditoría del cluster de desempeño crítico
#
# - La auditoría del cluster crítico, calculada ahora con estadísticas robustas (mediana), confirma que el grupo agrupa numerosas IES con medianas de puntaje global significativamente bajas y con amplia heterogeneidad entre instituciones.
# - Las estadísticas muestran que varias IES del cluster presentan medianas de puntaje muy bajas en Saber Pro, lo que refuerza la hipótesis de problemas persistentes en calidad formativa en esos casos.
# - Entre las instituciones con peor desempeño aparecen tanto universidades acreditadas como no acreditadas, y con tamaños muy distintos, por lo que la pertenencia al cluster no se explica únicamente por acreditación ni por volumen de matrícula.
# - Esta auditoría permite identificar una lista concreta de IES que requieren intervenciones focalizadas de política pública y apoyo en calidad, basándose en medidas robustas frente a outliers.
#
# <!-- AUTO_INTERPRETACION_auditoria -->

# %% [markdown]
# ## 10. Almacenamiento del Modelo y Metricas
# Guardamos el modelo entrenado (Pickle) y las metricas finales (JSON) para que puedan
# ser consumidos en fases posteriores o puestos en produccion.

# %%
# Estructura del modelo para exportacion
modelo_clustering = {
    'modelo': kmeans_final,
    'scaler': scaler,
    'pca': pca,
    'n_components_pca': N_COMPONENTS,
    'feature_names': features_ies.columns[:-1].tolist(),
    'labels': labels_final
}

fecha = datetime.now().strftime("%Y%m%d")
with open(ARTIFACTS_DIR / 'modelos' / f'clasificacion_ies_cluster_{fecha}.pkl', 'wb') as f:
    pickle.dump(modelo_clustering, f)

# Metricas JSON
metricas_clustering = {
    "metadata": {
        "modelo": "kmeans_ies_desempeno_pca",
        "fecha_entrenamiento": datetime.now().isoformat(),
        "autor": "German",
        "issue": "Sprint 7.2 - Clustering IES por desempeno (con PCA reducido)"
    },
    "datos": {
        "n_samples": int(len(features_ies)),
        "n_features_originales": int(X_scaled.shape[1]),
        "n_componentes_pca": int(N_COMPONENTS),
        "varianza_retenida_pca": float(pca.explained_variance_ratio_.sum()),
        "periodo": "2015-2024",
        "fuentes": ["Saber Pro", "SNIES"],
        "regla_matricula": "Sem1 todas IES + Sem2 solo SENA (MEN)"
    },
    "hiperparametros": {
        "algoritmo": "KMeans",
        "n_clusters": int(K_OPTIMO),
        "random_state": 42,
        "input_space": "PCA reduced"
    },
    "metricas_clustering": {
        "silhouette_score": float(silh_final),
        "davies_bouldin_index": float(db_final),
        "calinski_harabasz_score": float(ch_final)
    },
    "distribucion_clusters": {str(k): int(v) for k, v in features_ies['cluster'].value_counts().to_dict().items()},
    "features_utilizadas": features_ies.columns[:-1].tolist()
}

with open(ARTIFACTS_DIR / 'metricas' / f'metricas_clustering_{fecha}.json', 'w') as f:
    json.dump(metricas_clustering, f, indent=2)

print(f"\nModelo y metricas exportados exitosamente:")
print(f"  Modelo:   artifacts/modelos/clasificacion_ies_cluster_{fecha}.pkl")
print(f"  Metricas: artifacts/metricas/metricas_clustering_{fecha}.json")
print(f"\nResumen final:")
print(f"  {len(features_ies)} IES -> {K_OPTIMO} clusters")
print(f"  {X_scaled.shape[1]} features -> {N_COMPONENTS} componentes PCA ({pca.explained_variance_ratio_.sum()*100:.1f}% varianza)")
print(f"  Silhouette: {silh_final:.3f}")
# Out:
# Modelo y metricas exportados exitosamente:
#   Modelo:   artifacts/modelos/clasificacion_ies_cluster_20260524.pkl
#   Metricas: artifacts/metricas/metricas_clustering_20260524.json
#
# Resumen final:
#   336 IES -> 2 clusters
#   9 features -> 2 componentes PCA (79.1% varianza)
#   Silhouette: 0.675
